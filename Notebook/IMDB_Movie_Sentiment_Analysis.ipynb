# %%
from google.colab import drive
drive.mount('/content/drive')

from google.colab import files

# %% [markdown]
# # Contents
# [1. Libraries](#1)
# [2. Load Data](#2)
# [3. EDA and Data Visualization](#3)
# - [3.1 Data Description](#31)
# - [3.2 Target Distribution](#32)
# - [3.3 Wordcloud](#33)
#
# [4. Data Preprocessing](#4)
# [5. Multinomial Naive Bayes Model](#5)
#
# - [5.1 Define Model](#51)
# - [5.2 Define Features and Labels](#52)
# - [5.3 Fit and Predict Model](#53)
# - [5.4 Model Evaluation](#54)

# %% [markdown]
# # 1. Libraries
# <a name = '1'></a>

# %%
# !pip install wordcloud

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import seaborn as sns
from pylab import rcParams
import string
import re
import matplotlib.pyplot as plt
import math
from matplotlib import rc
from google.colab import drive
from sklearn.model_selection import train_test_split
from collections import Counter, defaultdict
from bs4 import BeautifulSoup
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report, confusion_matrix
import nltk
from nltk.corpus import stopwords
from wordcloud import WordCloud

# %matplotlib inline

sns.set(style='whitegrid', palette='muted', font_scale=1.5)

rcParams['figure.figsize'] = 14, 8

RANDOM_SEED = 42

np.random.seed(RANDOM_SEED)
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# # 2. Load Data
# <a name = '2'></a>

# %%
train = pd.read_csv("/content/drive/My Drive/Data Science/Projects/IMDB Movie Sentiment Analysis/labeledTrainData.tsv", delimiter="\t")
test = pd.read_csv("/content/drive/My Drive/Data Science/Projects/IMDB Movie Sentiment Analysis/testData.tsv", delimiter="\t")

# %%
train.head()
# Out:
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...

# %% [markdown]
# # 3. EDA and Data Visualization
# <a name = '3'></a>

# %% [markdown]
# ## 3.1 Data Description
# <a name = '31'></a>

# %%
train.describe()
# Out:
#          sentiment
# count  25000.00000
# mean       0.50000
# std        0.50001
# min        0.00000
# 25%        0.00000
# 50%        0.50000
# 75%        1.00000
# max        1.00000

# %%
train.shape
# Out:
# (25000, 3)

# %%
test.shape
# Out:
# (25000, 2)

# %% [markdown]
# ## 3.2 Target Distribution
# <a name = '32'></a>

# %%
f = sns.countplot(x='sentiment', data=train)
f.set_title("Sentiment distribution")
f.set_xticklabels(['Negative', 'Positive'])
plt.xlabel("");

# %% [markdown]
# ## 3.3 Wordcloud
# <a name = '33'></a>

# %%
text = " ".join(review for review in train.review)

wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white", stopwords=stopwords.words("english")).generate(text)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show();

# %% [markdown]
# # 4. Data Preprocessing
# <a name = '4'></a>

# %%
class Tokenizer:
  
  def clean(self, text):

      #Remove HTML Tags
      no_html = BeautifulSoup(text).get_text()
      
      #Filter Letters and Space
      clean = re.sub("[^a-z\s]+", " ", no_html, flags=re.IGNORECASE)
      
      #Replace Excessive Spacing with Single Space
      return re.sub("(\s+)", " ", clean)
 
  def tokenize(self, text):
      clean = self.clean(text).lower()

      #Remove Stopwords
      stopwords_en = stopwords.words("english")
      return [w for w in re.split("\W+", clean) if not w in stopwords_en]

# %% [markdown]
# # 5. Multinomial Naive Bayes Model
# <a name = '5'></a>

# %% [markdown]
# ## 5.1 Define Model
# <a name = '51'></a>

# %%
class MultinomialNaiveBayes:
  
    def __init__(self, classes, tokenizer):
      self.tokenizer = tokenizer
      self.classes = classes
      
    def group_by_class(self, X, y):
      data = dict()
      for c in self.classes:
        data[c] = X[np.where(y == c)]
      return data
           
    def fit(self, X, y):
        self.n_class_items = {}
        self.log_class_priors = {}
        self.word_counts = {}
        self.vocab = set()

        n = len(X)
        
        grouped_data = self.group_by_class(X, y)
        
        for c, data in grouped_data.items():
          self.n_class_items[c] = len(data)
          self.log_class_priors[c] = math.log(self.n_class_items[c] / n)
          self.word_counts[c] = defaultdict(lambda: 0)
          
          for text in data:
            counts = Counter(self.tokenizer.tokenize(text))
            for word, count in counts.items():
                if word not in self.vocab:
                    self.vocab.add(word)

                self.word_counts[c][word] += count
                
        return self
      
    def laplace_smoothing(self, word, text_class):
      num = self.word_counts[text_class][word] + 1
      denom = self.n_class_items[text_class] + len(self.vocab)
      return math.log(num / denom)
      
    def predict(self, X):
        result = []
        for text in X:
          
          class_scores = {c: self.log_class_priors[c] for c in self.classes}

          words = set(self.tokenizer.tokenize(text))
          for word in words:
              if word not in self.vocab: continue

              for c in self.classes:
                
                log_w_given_c = self.laplace_smoothing(word, c)
                class_scores[c] += log_w_given_c
                
          result.append(max(class_scores, key=class_scores.get))

        return result

# %% [markdown]
# ## 5.2 Define Features and Labels
# <a name = '52'></a>

# %%
X = train['review'].values
y = train['sentiment'].values
  
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=RANDOM_SEED)

# %% [markdown]
# ## 5.3 Fit and Predict Model
# <a name = '53'></a>

# %%
MNB = MultinomialNaiveBayes(
                            classes=np.unique(y), 
                            tokenizer=Tokenizer()
                            ).fit(X_train, y_train)

# %%
y_hat = MNB.predict(X_test)

# %% [markdown]
# ## 5.4 Model Evaluation
# <a name = '54'></a>

# %%
accuracy_score(y_test, y_hat)
# Out:
# 0.8556

# %%
from sklearn.metrics import f1_score

# %%
print(classification_report(y_test, y_hat))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.81      0.85      2481
#            1       0.83      0.90      0.86      2519
#
#     accuracy                           0.86      5000
#    macro avg       0.86      0.86      0.86      5000
# weighted avg       0.86      0.86      0.86      5000

# %%
cnf_matrix = confusion_matrix(y_test, y_hat)
cnf_matrix
# Out:
# array([[2021,  460],
#        [ 262, 2257]])

# %%
class_names = ["negative", "positive"]
fig,ax = plt.subplots()


sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="Blues", fmt="d", cbar=False, xticklabels=class_names, yticklabels=class_names)
ax.xaxis.set_label_position('top')
plt.tight_layout()
plt.ylabel('Actual sentiment')
plt.xlabel('Predicted sentiment');
